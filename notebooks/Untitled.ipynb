# %%
import datacube

print(datacube.__version__)
dc = datacube.Datacube(app="odc-jupyter-check")
products = dc.list_products()
products.head()
# Out:
# 1.9.18
#                               name  \
# name
# dummy_eo_product  dummy_eo_product
#
#                                                         description license  \
# name
# dummy_eo_product  Dữ liệu mẫu Earth Observation để test ODC chuẩ...    None
#
#                  default_crs default_resolution
# name
# dummy_eo_product        None               None
